# %%
import osmapi

api = osmapi.OsmApi(api="https://api06.dev.openstreetmap.org", username = "alexschalex", password = "amenabar")

# %% [markdown]
# https://geoffboeing.com/2016/11/osmnx-python-street-networks/

# %% [markdown]
# Paper sobre osmnx
# https://www.researchgate.net/publication/309738462_OSMnx_New_Methods_for_Acquiring_Constructing_Analyzing_and_Visualizing_Complex_Street_Networks

# %% [markdown]
# repo de ejemplos de uso
# https://github.com/gboeing/osmnx-examples/tree/master/notebooks

# %%
import osmnx as ox

city= ox.gdf_from_place('Barcelona, Spain')
ox.plot_shape(ox.project_gdf(city))
# Out:
# (<Figure size 432x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7ffa15235048>)

# %%
G=ox.graph_from_place('Barcelona, Spain', network_type='bike')
ox.plot_graph(G,fig_height=15,fig_width=10)
# Out:
# (<Figure size 720x1080 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7ffa0f0f4400>)

# %%
G=ox.graph_from_place('Barcelona, Spain', network_type='bike',retain_all=False)

ox.plot_graph(G,fig_height=15,fig_width=10,node_color='b')
# Out:
# (<Figure size 720x1080 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7ff9fb5f5ac8>)

# %%
ec = ['r' if data['oneway'] else 'b' for u, v, key, data in G.edges(keys=True, data=True)]
ox.plot_graph(G, node_size=0, edge_color=ec,fig_height=25,fig_width=15)
# Out:
# (<Figure size 1080x1800 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7ffa0e655748>)

# %%
import networkx as nx
#ROUTING:

# get the nearest network node to each point
orig_node = ox.get_nearest_node(G, (41.391052, 2.180645)) #arc d tionf
dest_node = ox.get_nearest_node(G, (41.3751984992, 2.12036451854))#camp nou

# find the route between these nodes then plot it
route = nx.shortest_path(G, orig_node, dest_node, weight='length')
fig, ax = ox.plot_graph_route(G, route, node_size=0,fig_height=15,fig_width=10)

# %%
#How long is the route in meters?
nx.shortest_path_length(G, orig_node, dest_node, weight='length')
# Out:
# 6146.0080000000025

# %% [markdown]
# Como bajar los datos para modificar los pesos:
#
# https://stackoverflow.com/questions/59322020/is-there-any-way-to-compute-networkx-dijkstras-algorithm-from-osmnx-graphs-with

# %% [markdown]
# Como usar un Graph Algorithm:
#
# https://www.geeksforgeeks.org/graph-data-structure-and-algorithms/#shortestPath

# %%
city_graph= ox.graph_from_place('Barcelona,Catalunya,Spain',retain_all=False , network_type='bike')

city_nodes, city_edges = ox.graph_to_gdfs(city_graph)

# %%
city_nodes
# Out:
#                     y         x       osmid highway  ref  \
# 412549129   41.408580  2.147194   412549129     NaN  NaN
# 412549130   41.407665  2.148066   412549130     NaN  NaN
# 412549132   41.407868  2.146323   412549132     NaN  NaN
# 412549133   41.405680  2.143774   412549133     NaN  NaN
# 412549137   41.405680  2.145332   412549137     NaN  NaN
# ...               ...       ...         ...     ...  ...
# 2582773744  41.356966  2.145013  2582773744     NaN  NaN
# 347340786   41.406186  2.198988   347340786     NaN  NaN
# 7026769911  41.443216  2.167604  7026769911     NaN  NaN
# 7026769912  41.443066  2.167219  7026769912     NaN  NaN
# 2268659706  41.396271  2.205179  2268659706     NaN  NaN
#
#                             geometry
# 412549129   POINT (2.14719 41.40858)
# 412549130   POINT (2.14807 41.40766)
# 412549132   POINT (2.14632 41.40787)
# 412549133   POINT (2.14377 41.40568)
# 412549137   POINT (2.14533 41.40568)
# ...                              ...
# 2582773744  POINT (2.14501 41.35697)
# 347340786   POINT (2.19899 41.40619)
# 7026769911  POINT (2.16760 41.44322)
# 7026769912  POINT (2.16722 41.44307)
# 2268659706  POINT (2.20518 41.39627)
#
# [17095 rows x 6 columns]

# %%
city_edges
# Out:
#                 u           v  key                              osmid oneway  \
# 0       412549129    30960821    0                           74621162   True
# 1       412549130  7095943437    0                           36726124   True
# 2       412549130   415950289    0  [486756070, 284386838, 486756071]   True
# 3       412549132    30960820    0                           34099200   True
# 4       412549132  1487379449    0                           35172817   True
# ...           ...         ...  ...                                ...    ...
# 36009  7026769911  2250836754    0                          215609929  False
# 36010  7026769911  2250836713    0                          215609929  False
# 36011  7026769912  7026769911    0                          751654978   True
# 36012  2268659706   347353582    0                          217581804   True
# 36013  2268659706   347712510    0                          404402533   True
#
#       lanes                                name         highway maxspeed  \
# 0         2  Avinguda de la República Argentina        tertiary       50
# 1         2                 Carrer de Velázquez     residential      NaN
# 2         2  Avinguda de la República Argentina        tertiary       50
# 3       NaN               Carrer de Ferran Puig     residential      NaN
# 4       NaN                    Carrer d'Escipió     residential      NaN
# ...     ...                                 ...             ...      ...
# 36009     1           Plaça d'Isabel de Villena     residential      NaN
# 36010     1           Plaça d'Isabel de Villena     residential      NaN
# 36011   NaN                                 NaN         service      NaN
# 36012   NaN                Carrer de la Llacuna  secondary_link      NaN
# 36013     1                                 NaN       secondary      NaN
#
#         length                                           geometry  \
# 0       43.873  LINESTRING (2.14719 41.40858, 2.14739 41.40834...
# 1       72.002  LINESTRING (2.14807 41.40766, 2.14817 41.40772...
# 2      168.370  LINESTRING (2.14807 41.40766, 2.14866 41.40719...
# 3       44.225    LINESTRING (2.14632 41.40787, 2.14668 41.40757)
# 4       65.618    LINESTRING (2.14632 41.40787, 2.14684 41.40831)
# ...        ...                                                ...
# 36009    8.987    LINESTRING (2.16760 41.44322, 2.16756 41.44329)
# 36010   84.751  LINESTRING (2.16760 41.44322, 2.16765 41.44315...
# 36011   36.234    LINESTRING (2.16722 41.44307, 2.16760 41.44322)
# 36012  106.372  LINESTRING (2.20518 41.39627, 2.20526 41.39623...
# 36013   20.690  LINESTRING (2.20518 41.39627, 2.20521 41.39628...
#
#              service    junction access width bridge  ref est_width tunnel  \
# 0                NaN         NaN    NaN   NaN    NaN  NaN       NaN    NaN
# 1                NaN         NaN    NaN   NaN    NaN  NaN       NaN    NaN
# 2                NaN         NaN    NaN   NaN    NaN  NaN       NaN    NaN
# 3                NaN         NaN    NaN   NaN    NaN  NaN       NaN    NaN
# 4                NaN         NaN    NaN   NaN    NaN  NaN       NaN    NaN
# ...              ...         ...    ...   ...    ...  ...       ...    ...
# 36009            NaN         NaN    NaN   NaN    NaN  NaN       NaN    NaN
# 36010            NaN         NaN    NaN   NaN    NaN  NaN       NaN    NaN
# 36011  parking_aisle         NaN    NaN   NaN    NaN  NaN       NaN    NaN
# 36012            NaN         NaN    NaN   NaN    NaN  NaN       NaN    NaN
# 36013            NaN  roundabout    NaN     6    NaN  NaN       NaN    NaN
#
#       area
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 36009  NaN
# 36010  NaN
# 36011  NaN
# 36012  NaN
# 36013  NaN
#
# [36014 rows x 20 columns]

# %%
import numpy as np
#creando una columna random para usar como nuevos pesos.
city_edges['test1']=np.random.randint(1,3000,city_edges.shape[0])

# %%
#creo nuevo graph para poder usar los pesos de test1
updated_city_graph=ox.gdfs_to_graph(city_nodes,city_edges)

# %%
orig_node = ox.get_nearest_node(updated_city_graph, (41.391052, 2.180645)) #arc d tionf
dest_node = ox.get_nearest_node(updated_city_graph, (41.3751984992, 2.12036451854))#camp nou

# find the route between these nodes then plot it
route = nx.shortest_path(updated_city_graph, orig_node, dest_node, weight='length')
fig, ax = ox.plot_graph_route(G, route, node_size=0,fig_height=15,fig_width=10)

# %%
orig_node = ox.get_nearest_node(updated_city_graph, (41.391052, 2.180645)) #arc d tionf
dest_node = ox.get_nearest_node(updated_city_graph, (41.3751984992, 2.12036451854))#camp nou

# find the route between these nodes then plot it
route = nx.shortest_path(updated_city_graph, orig_node, dest_node, weight='test1')
fig, ax = ox.plot_graph_route(updated_city_graph, route, node_size=0,fig_height=15,fig_width=10)

# %%
test1_path = nx.dijkstra_path(updated_city_graph, source = 30237607, target = 30254084, weight = 'test1')
fig, ax = ox.plot_graph_route(updated_city_graph, test1_path, node_size=0,fig_height=15,fig_width=10)
